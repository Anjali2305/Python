# %%
logo = """
  / _ \_   _  ___  ___ ___  /__   \ |__   ___    /\ \ \_   _ _ __ ___ | |__   ___ _ __ 
 / /_\/ | | |/ _ \/ __/ __|   / /\/ '_ \ / _ \  /  \/ / | | | '_ ` _ \| '_ \ / _ \ '__|
/ /_\\| |_| |  __/\__ \__ \  / /  | | | |  __/ / /\  /| |_| | | | | | | |_) |  __/ |   
\____/ \__,_|\___||___/___/  \/   |_| |_|\___| \_\ \/  \__,_|_| |_| |_|_.__/ \___|_|  
"""

# %% [markdown]
# # Simple

# %%
import random
com_number = random.randint(1,100)
print(logo)
print("Welcome to the Number Guessing Game!!!")
print("I am thinking of a number between 1 to 100")
level = input("Choose a diffivulty level - 'Easy' or 'Hard'")

if level.lower() == 'easy':
  attempt = 10
  print(f"You Have total {attempt} attempts")
elif level.lower() == 'hard':
  attempt = 5
  print(f"You Have total {attempt} attempts")
else:
  print(" Wrong Choice Broo!!!")

def check(u_number):

  if (u_number > com_number ):
    text = "Too high!!"
  elif (u_number<com_number):
    text= "Too low"
  else:
    text = "Match"
  return text



while attempt>0:
  user_number= int(input("Make a Guess : "))
  guess = check(user_number)
  if guess  == "Match":
    print(f"Congratulations !! Your guess is right {user_number}")
    attempt = 0
  else :
    
    attempt-=1
    if attempt == 0:
      print(f" Attempt finish, Right number is {com_number}")
    else :
      print(guess)
      print(f"you have {attempt} remaining to guess the number")
      print("Guess again.")
# Out:
#   / _ \_   _  ___  ___ ___  /__   \ |__   ___    /\ \ \_   _ _ __ ___ | |__   ___ _ __
#  / /_\/ | | |/ _ \/ __/ __|   / /\/ '_ \ / _ \  /  \/ / | | | '_ ` _ \| '_ \ / _ \ '__|
# / /_\| |_| |  __/\__ \__ \  / /  | | | |  __/ / /\  /| |_| | | | | | | |_) |  __/ |
# \____/ \__,_|\___||___/___/  \/   |_| |_|\___| \_\ \/  \__,_|_| |_| |_|_.__/ \___|_|
#
# Welcome to the Number Guessing Game!!!
# I am thinking of a number between 1 to 100
# Choose a diffivulty level - 'Easy' or 'Hard'hard
# You Have total 5 attempts
# Make a Guess : 52
# Too low
# you have 4 remaining to guess the number
# Guess again.
# Make a Guess : 96
# Congratulations !! Your guess is right 96

# %% [markdown]
# # Second Way

# %%
from random import randint


EASY_LEVEL_TURNS = 10
HARD_LEVEL_TURNS = 5

#Function to check user's guess against actual answer.
def check_answer(guess, answer, turns):
  """checks answer against guess. Returns the number of turns remaining."""
  if guess > answer:
    print("Too high.")
    return turns - 1
  elif guess < answer:
    print("Too low.")
    return turns - 1
  else:
    print(f"You got it! The answer was {answer}.")

#Make function to set difficulty.
def set_difficulty():
  level = input("Choose a difficulty. Type 'easy' or 'hard': ")
  if level == "easy":
    return EASY_LEVEL_TURNS
  else:
    return HARD_LEVEL_TURNS

def game():
  print(logo)
  #Choosing a random number between 1 and 100.
  print("Welcome to the Number Guessing Game!")
  print("I'm thinking of a number between 1 and 100.")
  answer = randint(1, 100)
  print(f"Pssst, the correct answer is {answer}") 

  turns = set_difficulty()
  #Repeat the guessing functionality if they get it wrong.
  guess = 0
  while guess != answer:
    print(f"You have {turns} attempts remaining to guess the number.")

    #Let the user guess a number.
    guess = int(input("Make a guess: "))

    #Track the number of turns and reduce by 1 if they get it wrong.
    turns = check_answer(guess, answer, turns)
    if turns == 0:
      print("You've run out of guesses, you lose.")
      return
    elif guess != answer:
      print("Guess again.")


game()
# Out:
#   / _ \_   _  ___  ___ ___  /__   \ |__   ___    /\ \ \_   _ _ __ ___ | |__   ___ _ __
#  / /_\/ | | |/ _ \/ __/ __|   / /\/ '_ \ / _ \  /  \/ / | | | '_ ` _ \| '_ \ / _ \ '__|
# / /_\| |_| |  __/\__ \__ \  / /  | | | |  __/ / /\  /| |_| | | | | | | |_) |  __/ |
# \____/ \__,_|\___||___/___/  \/   |_| |_|\___| \_\ \/  \__,_|_| |_| |_|_.__/ \___|_|
#
# Welcome to the Number Guessing Game!
# I'm thinking of a number between 1 and 100.
# Pssst, the correct answer is 94
# Choose a difficulty. Type 'easy' or 'hard': hard
# You have 5 attempts remaining to guess the number.
# Make a guess: 25
# Too low.
# Guess again.
# You have 4 attempts remaining to guess the number.
# Make a guess: 62
# Too low.
# Guess again.
# You have 3 attempts remaining to guess the number.
# Make a guess: 92
# Too low.
# Guess again.
# You have 2 attempts remaining to guess the number.
# Make a guess: 96
# Too high.
# Guess again.
# You have 1 attempts remaining to guess the number.
# Make a guess: 94
# ...
